# %% [markdown]
# # Setup
#
# **Step 1**: Import Semantic Kernel SDK from pypi.org

# %%
# !python -m pip install semantic-kernel==0.9.4b1
# Out:
# Collecting semantic-kernel==0.9.4b1
#   Downloading semantic_kernel-0.9.4b1-py3-none-any.whl.metadata (5.2 kB)
# Collecting aiohttp<4.0,>=3.8 (from semantic-kernel==0.9.4b1)
#   Downloading aiohttp-3.9.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Collecting defusedxml<0.8.0,>=0.7.1 (from semantic-kernel==0.9.4b1)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting grpcio>=1.50.0 (from semantic-kernel==0.9.4b1)
#   Downloading grpcio-1.62.1-cp312-cp312-macosx_10_10_universal2.whl.metadata (4.0 kB)
# Collecting jinja2<4.0.0,>=3.1.3 (from semantic-kernel==0.9.4b1)
#   Downloading Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting motor<4.0.0,>=3.3.2 (from semantic-kernel==0.9.4b1)
#   Downloading motor-3.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.6.0 in /Users/philip.levy/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from semantic-kernel==0.9.4b1) (1.6.0)
# Collecting numpy>=1.26 (from semantic-kernel==0.9.4b1)
#   Downloading numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.6 MB/s eta 0:00:00
# Collecting openai>=1.0 (from semantic-kernel==0.9.4b1)
#   Downloading openai-1.14.3-py3-none-any.whl.metadata (20 kB)
# Collecting openapi_core<0.20,>=0.18 (from semantic-kernel==0.9.4b1)
#   Downloading openapi_core-0.19.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting prance<24.0.0.0,>=23.6.21.0 (from semantic-kernel==0.9.4b1)
#   Downloading prance-23.6.21.0-py3-none-any.whl.metadata (13 kB)
# Collecting pybars4<0.10.0,>=0.9.13 (from semantic-kernel==0.9.4b1)
#   Downloading pybars4-0.9.13.tar.gz (29 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pydantic<3,>=2 (from semantic-kernel==0.9.4b1)
#   Downloading pydantic-2.6.4-py3-none-any.whl.metadata (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.1/85.1 kB 4.7 MB/s eta 0:00:00
# Collecting python-dotenv<2.0.0,>=1.0.1 (from semantic-kernel==0.9.4b1)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting regex<2024.0.0,>=2023.6.3 (from semantic-kernel==0.9.4b1)
#   Downloading regex-2023.12.25-cp312-cp312-macosx_11_0_arm64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 3.5 MB/s eta 0:00:00
# Collecting scipy>=1.12.0 (from semantic-kernel==0.9.4b1)
#   Downloading scipy-1.12.0-cp312-cp312-macosx_12_0_arm64.whl.metadata (217 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.9/217.9 kB 5.9 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0,>=3.8->semantic-kernel==0.9.4b1)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0,>=3.8->semantic-kernel==0.9.4b1)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0,>=3.8->semantic-kernel==0.9.4b1)
#   Downloading frozenlist-1.4.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0,>=3.8->semantic-kernel==0.9.4b1)
#   Downloading multidict-6.0.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0,>=3.8->semantic-kernel==0.9.4b1)
#   Downloading yarl-1.9.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (31 kB)
# Collecting MarkupSafe>=2.0 (from jinja2<4.0.0,>=3.1.3->semantic-kernel==0.9.4b1)
#   Downloading MarkupSafe-2.1.5-cp312-cp312-macosx_10_9_universal2.whl.metadata (3.0 kB)
# Collecting pymongo<5,>=4.5 (from motor<4.0.0,>=3.3.2->semantic-kernel==0.9.4b1)
#   Downloading pymongo-4.6.3-cp312-cp312-macosx_10_9_universal2.whl.metadata (22 kB)
# Collecting anyio<5,>=3.5.0 (from openai>=1.0->semantic-kernel==0.9.4b1)
#   Downloading anyio-4.3.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro<2,>=1.7.0 (from openai>=1.0->semantic-kernel==0.9.4b1)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai>=1.0->semantic-kernel==0.9.4b1)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting sniffio (from openai>=1.0->semantic-kernel==0.9.4b1)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai>=1.0->semantic-kernel==0.9.4b1)
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 4.2 MB/s eta 0:00:00
# Collecting typing-extensions<5,>=4.7 (from openai>=1.0->semantic-kernel==0.9.4b1)
#   Downloading typing_extensions-4.10.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting isodate (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.4b1)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Collecting jsonschema<5.0.0,>=4.18.0 (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.4b1)
#   Downloading jsonschema-4.21.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting jsonschema-path<0.4.0,>=0.3.1 (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.4b1)
#   Downloading jsonschema_path-0.3.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting more-itertools (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.4b1)
#   Downloading more_itertools-10.2.0-py3-none-any.whl.metadata (34 kB)
# Collecting openapi-schema-validator<0.7.0,>=0.6.0 (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.4b1)
#   Downloading openapi_schema_validator-0.6.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting openapi-spec-validator<0.8.0,>=0.7.1 (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.4b1)
#   Downloading openapi_spec_validator-0.7.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting parse (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.4b1)
#   Downloading parse-1.20.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting werkzeug (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.4b1)
#   Downloading werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting chardet>=3.0 (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.4b1)
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting ruamel.yaml>=0.17.10 (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.4b1)
#   Downloading ruamel.yaml-0.18.6-py3-none-any.whl.metadata (23 kB)
# Collecting requests>=2.25 (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.4b1)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: six~=1.15 in /Users/philip.levy/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.4b1) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in /Users/philip.levy/.pyenv/versions/3.12.2/lib/python3.12/site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.4b1) (24.0)
# Collecting PyMeta3>=0.5.1 (from pybars4<0.10.0,>=0.9.13->semantic-kernel==0.9.4b1)
#   Downloading PyMeta3-0.5.1.tar.gz (29 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=2->semantic-kernel==0.9.4b1)
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.16.3 (from pydantic<3,>=2->semantic-kernel==0.9.4b1)
#   Downloading pydantic_core-2.16.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.5 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->openai>=1.0->semantic-kernel==0.9.4b1)
#   Downloading idna-3.6-py3-none-any.whl.metadata (9.9 kB)
# Collecting certifi (from httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==0.9.4b1)
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==0.9.4b1)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==0.9.4b1)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==0.9.4b1)
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==0.9.4b1)
#   Downloading referencing-0.34.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==0.9.4b1)
#   Downloading rpds_py-0.18.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting PyYAML>=5.1 (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel==0.9.4b1)
#   Downloading PyYAML-6.0.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting pathable<0.5.0,>=0.4.1 (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel==0.9.4b1)
#   Downloading pathable-0.4.3-py3-none-any.whl.metadata (1.9 kB)
# Collecting referencing>=0.28.4 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==0.9.4b1)
#   Downloading referencing-0.31.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting rfc3339-validator (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel==0.9.4b1)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting lazy-object-proxy<2.0.0,>=1.7.1 (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel==0.9.4b1)
#   Downloading lazy-object-proxy-1.10.0.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 4.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo<5,>=4.5->motor<4.0.0,>=3.3.2->semantic-kernel==0.9.4b1)
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.4b1)
#   Downloading charset_normalizer-3.3.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (33 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.4b1)
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.10->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.4b1)
#   Downloading ruamel.yaml.clib-0.2.8-cp312-cp312-macosx_13_0_arm64.whl.metadata (2.2 kB)
# Downloading semantic_kernel-0.9.4b1-py3-none-any.whl (265 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.5/265.5 kB 15.3 MB/s eta 0:00:00
# Downloading aiohttp-3.9.3-cp312-cp312-macosx_11_0_arm64.whl (389 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.7/389.7 kB 8.8 MB/s eta 0:00:00:00:01
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading grpcio-1.62.1-cp312-cp312-macosx_10_10_universal2.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 8.4 MB/s eta 0:00:0000:010:01m
# Downloading Jinja2-3.1.3-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 kB 4.0 MB/s eta 0:00:00
# Downloading motor-3.4.0-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 4.2 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl (13.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 1.9 MB/s eta 0:00:0000:0100:01
# Downloading openai-1.14.3-py3-none-any.whl (262 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.9/262.9 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Downloading openapi_core-0.19.0-py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.7/100.7 kB 1.7 MB/s eta 0:00:00 0:00:01
# Downloading prance-23.6.21.0-py3-none-any.whl (36 kB)
# Downloading pydantic-2.6.4-py3-none-any.whl (394 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.9/394.9 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Downloading pydantic_core-2.16.3-cp312-cp312-macosx_11_0_arm64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 2.1 MB/s eta 0:00:0000:0100:01
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading regex-2023.12.25-cp312-cp312-macosx_11_0_arm64.whl (292 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.2/292.2 kB 3.0 MB/s eta 0:00:00a 0:00:01
# Downloading scipy-1.12.0-cp312-cp312-macosx_12_0_arm64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 2.1 MB/s eta 0:00:0000:0100:01
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading anyio-4.3.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 2.2 MB/s eta 0:00:00
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.4/199.4 kB 1.7 MB/s eta 0:00:0000:0100:01
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading frozenlist-1.4.1-cp312-cp312-macosx_11_0_arm64.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 2.0 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 2.1 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Downloading jsonschema-4.21.1-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Downloading jsonschema_path-0.3.2-py3-none-any.whl (14 kB)
# Downloading MarkupSafe-2.1.5-cp312-cp312-macosx_10_9_universal2.whl (18 kB)
# Downloading multidict-6.0.5-cp312-cp312-macosx_11_0_arm64.whl (29 kB)
# Downloading openapi_schema_validator-0.6.2-py3-none-any.whl (8.8 kB)
# Downloading openapi_spec_validator-0.7.1-py3-none-any.whl (38 kB)
# Downloading pymongo-4.6.3-cp312-cp312-macosx_10_9_universal2.whl (533 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 533.5/533.5 kB 2.1 MB/s eta 0:00:00a 0:00:01
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 2.0 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 2.4 MB/s eta 0:00:00 0:00:01
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 2.1 MB/s eta 0:00:00a 0:00:01
# Using cached typing_extensions-4.10.0-py3-none-any.whl (33 kB)
# Downloading yarl-1.9.4-cp312-cp312-macosx_11_0_arm64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.4/79.4 kB 2.4 MB/s eta 0:00:00
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.5 MB/s eta 0:00:00
# Downloading more_itertools-10.2.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 2.3 MB/s eta 0:00:00
# Downloading parse-1.20.1-py2.py3-none-any.whl (20 kB)
# Downloading werkzeug-3.0.1-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 2.6 MB/s eta 0:00:00a 0:00:01
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 2.8 MB/s eta 0:00:00a 0:00:01
# Downloading charset_normalizer-3.3.2-cp312-cp312-macosx_11_0_arm64.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 2.4 MB/s eta 0:00:00a 0:00:01
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 2.7 MB/s eta 0:00:0000:0100:01
# Downloading idna-3.6-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 2.9 MB/s eta 0:00:00
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading pathable-0.4.3-py3-none-any.whl (9.6 kB)
# Downloading PyYAML-6.0.1-cp312-cp312-macosx_11_0_arm64.whl (165 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 2.9 MB/s eta 0:00:00a 0:00:01
# Downloading referencing-0.31.1-py3-none-any.whl (25 kB)
# Downloading rpds_py-0.18.0-cp312-cp312-macosx_11_0_arm64.whl (332 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.0/333.0 kB 2.9 MB/s eta 0:00:0000:0100:01
# Downloading ruamel.yaml.clib-0.2.8-cp312-cp312-macosx_13_0_arm64.whl (135 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.7/135.7 kB 2.6 MB/s eta 0:00:00 0:00:01
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 2.6 MB/s eta 0:00:00a 0:00:01
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.4 MB/s eta 0:00:00
# Building wheels for collected packages: pybars4, PyMeta3, lazy-object-proxy
#   Building wheel for pybars4 (pyproject.toml) ... done
#   Created wheel for pybars4: filename=pybars4-0.9.13-py3-none-any.whl size=14340 sha256=85a2093b1427d1a5a3cd028215cbea612f17094c7f29aae7a5eb0281214b93ea
#   Stored in directory: /Users/philip.levy/Library/Caches/pip/wheels/75/2d/da/c75b2fc7b00dc9c154dff65f689a318e7d24b44c612c2b21f1
#   Building wheel for PyMeta3 (pyproject.toml) ... done
#   Created wheel for PyMeta3: filename=PyMeta3-0.5.1-py3-none-any.whl size=16448 sha256=4452e9c8e2b969b82cd77b2f25efd4203cdb7eb280d31809606333cf519f74b5
#   Stored in directory: /Users/philip.levy/Library/Caches/pip/wheels/5a/9b/2c/81b7551d2c05a482817e6c3b3d2f8ad2a0229db874c4bc6346
#   Building wheel for lazy-object-proxy (pyproject.toml) ... done
#   Created wheel for lazy-object-proxy: filename=lazy_object_proxy-1.10.0-cp312-cp312-macosx_14_0_arm64.whl size=27530 sha256=dadb644ab5f7663d3411d27984384b19560f2e737f58057de8a790ab6402be2b
#   Stored in directory: /Users/philip.levy/Library/Caches/pip/wheels/96/f0/2f/ef3ca53a41cb910753c8bf098e9a62277a7e5834d8d9c14ade
# Successfully built pybars4 PyMeta3 lazy-object-proxy
# Installing collected packages: PyMeta3, parse, urllib3, typing-extensions, tqdm, sniffio, ruamel.yaml.clib, rpds-py, rfc3339-validator, regex, PyYAML, python-dotenv, pybars4, pathable, numpy, multidict, more-itertools, MarkupSafe, lazy-object-proxy, isodate, idna, h11, grpcio, frozenlist, dnspython, distro, defusedxml, charset-normalizer, chardet, certifi, attrs, annotated-types, yarl, werkzeug, scipy, ruamel.yaml, requests, referencing, pymongo, pydantic-core, jinja2, httpcore, anyio, aiosignal, pydantic, prance, motor, jsonschema-specifications, jsonschema-path, httpx, aiohttp, openai, jsonschema, openapi-schema-validator, openapi-spec-validator, openapi_core, semantic-kernel
# Successfully installed MarkupSafe-2.1.5 PyMeta3-0.5.1 PyYAML-6.0.1 aiohttp-3.9.3 aiosignal-1.3.1 annotated-types-0.6.0 anyio-4.3.0 attrs-23.2.0 certifi-2024.2.2 chardet-5.2.0 charset-normalizer-3.3.2 defusedxml-0.7.1 distro-1.9.0 dnspython-2.6.1 frozenlist-1.4.1 grpcio-1.62.1 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 idna-3.6 isodate-0.6.1 jinja2-3.1.3 jsonschema-4.21.1 jsonschema-path-0.3.2 jsonschema-specifications-2023.12.1 lazy-object-proxy-1.10.0 more-itertools-10.2.0 motor-3.4.0 multidict-6.0.5 numpy-1.26.4 openai-1.14.3 openapi-schema-validator-0.6.2 openapi-spec-validator-0.7.1 openapi_core-0.19.0 parse-1.20.1 pathable-0.4.3 prance-23.6.21.0 pybars4-0.9.13 pydantic-2.6.4 pydantic-core-2.16.3 pymongo-4.6.3 python-dotenv-1.0.1 referencing-0.31.1 regex-2023.12.25 requests-2.31.0 rfc3339-validator-0.1.4 rpds-py-0.18.0 ruamel.yaml-0.18.6 ruamel.yaml.clib-0.2.8 scipy-1.12.0 semantic-kernel-0.9.4b1 sniffio-1.3.1 tqdm-4.66.2 typing-extensions-4.10.0 urllib3-2.2.1 werkzeug-3.0.1 yarl-1.9.4

# %%
import semantic_kernel as sk

kernel = sk.Kernel()

# %% [markdown]
# ### Configure the service you'd like to use via the `Service` Enum.

# %%
from services import Service

# Select a service to use for this notebook (available services: OpenAI, AzureOpenAI, HuggingFace)
selectedService = Service.OpenAI

# %% [markdown]
# ## Option 1: using OpenAI
#
# **Step 2**: Add your [OpenAI Key](https://openai.com/product/) key to a `.env` file in the same folder (org Id only if you have multiple orgs):
#
# ```
# OPENAI_API_KEY="sk-..."
# OPENAI_ORG_ID=""
# ```
#
# Use "keyword arguments" to instantiate an OpenAI Chat Completion service and add it to the kernel:
#
# ## Option 2: using Azure OpenAI
#
# **Step 2**: Add your [Azure Open AI Service key](https://learn.microsoft.com/azure/cognitive-services/openai/quickstart?pivots=programming-language-studio) settings to a `.env` file in the same folder:
#
# ```
# AZURE_OPENAI_API_KEY="..."
# AZURE_OPENAI_ENDPOINT="https://..."
# AZURE_OPENAI_DEPLOYMENT_NAME="..."
# ```
#
# Use "keyword arguments" to instantiate an Azure OpenAI Chat Completion service and add it to the kernel:

# %%
service_id = None
if selectedService == Service.OpenAI:
    from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion

    api_key, org_id = sk.openai_settings_from_dot_env()
    service_id = "default"
    kernel.add_service(
        OpenAIChatCompletion(service_id=service_id, ai_model_id="gpt-3.5-turbo-1106", api_key=api_key, org_id=org_id),
    )
elif selectedService == Service.AzureOpenAI:
    from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

    deployment, api_key, endpoint = sk.azure_openai_settings_from_dot_env()
    service_id = "default"
    kernel.add_service(
        AzureChatCompletion(service_id=service_id, deployment_name=deployment, endpoint=endpoint, api_key=api_key),
    )

# %% [markdown]
# # Run a Semantic Function
#
# **Step 3**: Load a Plugin and run a semantic function:

# %%
plugin = kernel.import_plugin_from_prompt_directory("../../samples/plugins", "FunPlugin")

# %%
joke_function = plugin["Joke"]

joke = await kernel.invoke(joke_function, sk.KernelArguments(input="time travel to dinosaur age", style="super silly"))
print(joke)
# Out:
# Why don't dinosaurs ever use time machines?
#
# Because they're afraid of getting a dino-sore!
